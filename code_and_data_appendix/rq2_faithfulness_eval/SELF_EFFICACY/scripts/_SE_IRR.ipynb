# %%
from google.colab import drive
drive.mount('/content/drive')

from sklearn.metrics import cohen_kappa_score
import pandas as pd
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
DATA_PATH = ""

# %%
df = pd.read_csv(DATA_PATH)

assert not df.self_efficacy_score.isna().any()
assert not df.consensus_score.isna().any()

df.head()

# %%
judge_scores, consensus_scores = df.self_efficacy_score, df.consensus_score

print(cohen_kappa_score(judge_scores,consensus_scores,weights='quadratic'))
# Out:
# 0.9276759884281581
