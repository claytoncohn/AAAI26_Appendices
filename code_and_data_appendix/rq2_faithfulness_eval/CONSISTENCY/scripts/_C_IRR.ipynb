# %%
from google.colab import drive
drive.mount('/content/drive')

from sklearn.metrics import cohen_kappa_score
import pandas as pd
# Out:
# Mounted at /content/drive

# %%
DATA_PATH = ""

# %%
df = pd.read_csv(DATA_PATH)

assert not df.consistency_score.isna().any()
assert not df.consensus_score.isna().any()

df.head()

# %%
judge_scores, consensus_scores = df.consistency_score, df.consensus_score

print(cohen_kappa_score(judge_scores, consensus_scores))
# Out:
# 0.8780487804878049
